# %% [markdown]
# # END TO END DATA ANALYSIS PROJECT- BANKING ANALYSIS

# %% [markdown]
# ## 📦 IMPORT REQUIRED LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Connecting SQL and Python

# %%
import mysql.connector

cnx = mysql.connector.connect(
    host="127.0.0.1",
    port=3306,
    user="root",
    password="Black123@")

# %%
query="SELECT *FROM BANKING_DATA.Customer";

# %%
df=pd.read_sql(query,cnx)
# Out:
# C:\Users\91910\AppData\Local\Temp\ipykernel_2828\3864670969.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(query,cnx)

# %%
print(df)
# Out:
#      Client ID              Name  Age  Location ID Joined Bank  \
# 0     IND81288     Raymond Mills   24        34324  06-05-2019
# 1     IND65833     Julia Spencer   23        42205  10-12-2001
# 2     IND47499    Stephen Murray   27         7314  25-01-2010
# 3     IND72498    Virginia Garza   40        34594  28-03-2019
# 4     IND60181   Melissa Sanders   46        41269  20-07-2012
# ...        ...               ...  ...          ...         ...
# 2995  IND66827         Earl Hall   82         8760  09-10-2014
# 2996  IND40556  Billy Williamson   44        32837  05-02-2009
# 2997  IND72414      Victor Black   70        36088  29-12-2009
# 2998  IND46652       Andrew Ford   56        24871  13-02-2006
# 2999  IND40216        Amy Nguyen   79        38518  08-12-2005
#
#           Banking Contact Nationality                     Occupation  \
# 0          Anthony Torres    American           Safety Technician IV
# ...

# %% [markdown]
# ## SAMPLE DATA

# %%
df.head()
# Out:
#   Client ID             Name  Age  Location ID Joined Bank   Banking Contact  \
# 0  IND81288    Raymond Mills   24        34324  06-05-2019    Anthony Torres
# 1  IND65833    Julia Spencer   23        42205  10-12-2001  Jonathan Hawkins
# 2  IND47499   Stephen Murray   27         7314  25-01-2010     Anthony Berry
# 3  IND72498   Virginia Garza   40        34594  28-03-2019        Steve Diaz
# 4  IND60181  Melissa Sanders   46        41269  20-07-2012        Shawn Long
#
#   Nationality            Occupation Fee Structure Loyalty Classification  ...  \
# 0    American  Safety Technician IV          High                   Jade  ...
# 1     African   Software Consultant          High                   Jade  ...
# 2    European    Help Desk Operator          High                   Gold  ...
# 3    American          Geologist II           Mid                 Silver  ...
# 4    American   Assistant Professor           Mid               Platinum  ...
#
# ...

# %%
df.tail()
# Out:
#      Client ID              Name  Age  Location ID Joined Bank  \
# 2995  IND66827         Earl Hall   82         8760  09-10-2014
# 2996  IND40556  Billy Williamson   44        32837  05-02-2009
# 2997  IND72414      Victor Black   70        36088  29-12-2009
# 2998  IND46652       Andrew Ford   56        24871  13-02-2006
# 2999  IND40216        Amy Nguyen   79        38518  08-12-2005
#
#           Banking Contact Nationality                     Occupation  \
# 2995       Joshua Bennett    American       Accounting Assistant III
# 2996          Dennis Ruiz    European                      Paralegal
# 2997          Joshua Ryan    American                Statistician IV
# 2998  Nicholas Cunningham    European  Human Resources Assistant III
# 2999           Joe Hanson    American            Biostatistician III
#
#      Fee Structure Loyalty Classification  ...  Bank Deposits  \
# 2995          High                   Gold  ...     1089957.03
# ...

# %% [markdown]
# ## SHAPE AND SUMMARY OF THE DATAFRAME

# %%
print("Shape of the DataFrame:", df.shape)

print("\nDataFrame Info:")
df.info()
# Out:
# Shape of the DataFrame: (3000, 25)
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Client ID                 3000 non-null   object
#  1   Name                      3000 non-null   object
#  2   Age                       3000 non-null   int64
#  3   Location ID               3000 non-null   int64
#  4   Joined Bank               3000 non-null   object
#  5   Banking Contact           3000 non-null   object
#  6   Nationality               3000 non-null   object
#  7   Occupation                3000 non-null   object
#  8   Fee Structure             3000 non-null   object
#  9   Loyalty Classification    3000 non-null   object
#  10  Estimated Income          3000 non-null   float64
#  11  Superannuation Savings    3000 non-null   float64
# ...

# %% [markdown]
# ## ESTIMATED INCOME OF THE CUSTOMERS

# %%
df["Estimated Income"]
# Out:
# 0        75384.77
# 1       289834.31
# 2       169935.23
# 3       356808.11
# 4       130711.68
#           ...
# 2995    297617.14
# 2996     42397.46
# 2997     48339.88
# 2998    107265.87
# 2999     56826.53
# Name: Estimated Income, Length: 3000, dtype: float64

# %%
# Define income band boundaries
bins = [0, 100000, 300000, float('inf')]
labels = ['Low', 'Mid', 'High']

# Create the 'Income Band' column using pd.cut
df['Income Band'] = pd.cut(df['Estimated Income'], bins=bins, labels=labels, include_lowest=True)

# %% [markdown]
# ## Examine the distribution of unique categories in categorical columns

# %%
categorical_cols = df[["Risk Weighting","Nationality","Occupation","Fee Structure","Loyalty Classification","Properties Owned","Risk Weighting","Occupation","Income Band"]].columns
for col in categorical_cols:
  # if col in ["Client ID","Name","Joined Bank"]:
  #   continue
  print(f"\nValue Counts for '{col}':")
  display(df[col].value_counts())
# Out:
# Value Counts for 'Risk Weighting':
# Risk Weighting
# 2    1222
# 1     836
# 3     460
# 4     322
# 5     160
# Name: count, dtype: int64
# Value Counts for 'Nationality':
# Nationality
# European      1309
# Asian          754
# American       507
# Australian     254
# African        176
# Name: count, dtype: int64
# Value Counts for 'Occupation':
# Occupation
# Associate Professor             28
# Structural Analysis Engineer    28
# Recruiter                       25
# Account Coordinator             24
# Human Resources Manager         24
#                                 ..
# Office Assistant IV              8
# Automation Specialist I          7
# Computer Systems Analyst I       6
# Developer III                    5
# Senior Sales Associate           4
# Name: count, Length: 195, dtype: int64
# Value Counts for 'Fee Structure':
# Fee Structure
# High    1476
# Mid      962
# Low      562
# Name: count, dtype: int64
# Value Counts for 'Loyalty Classification':
# ...

# %% [markdown]
# ## Generate descriptive statistics for numerical columns

# %%
print("\nDescriptive Statistics for Numerical Columns:")
display(df.describe())
# Out:
# Descriptive Statistics for Numerical Columns:
#                Age   Location ID  Estimated Income  Superannuation Savings  \
# count  3000.000000   3000.000000       3000.000000             3000.000000
# mean     51.039667  21563.323000     171305.034263            25531.599673
# std      19.854760  12462.273017     111935.808209            16259.950770
# min      17.000000     12.000000      15919.480000             1482.030000
# 25%      34.000000  10803.500000      82906.595000            12513.775000
# 50%      51.000000  21129.500000     142313.480000            22357.355000
# 75%      69.000000  32054.500000     242290.305000            35464.740000
# max      85.000000  43369.000000     522330.260000            75963.900000
#
#        Amount of Credit Cards  Credit Card Balance    Bank Loans  \
# count             3000.000000          3000.000000  3.000000e+03
# mean                 1.463667          3176.206943  5.913862e+05
# ...

# %% [markdown]
# ## Check for missing values

# %%
missing_values = df.isnull().sum()
print("Missing values per column:\n", missing_values)
# Out:
# Missing values per column:
#  Client ID                   0
# Name                        0
# Age                         0
# Location ID                 0
# Joined Bank                 0
# Banking Contact             0
# Nationality                 0
# Occupation                  0
# Fee Structure               0
# Loyalty Classification      0
# Estimated Income            0
# Superannuation Savings      0
# Amount of Credit Cards      0
# Credit Card Balance         0
# Bank Loans                  0
# Bank Deposits               0
# Checking Accounts           0
# Saving Accounts             0
# Foreign Currency Account    0
# Business Lending            0
# Properties Owned            0
# Risk Weighting              0
# BRId                        0
# GenderId                    0
# IAId                        0
# Income Band                 0
# dtype: int64

# %%
df['Joined Bank'] = pd.to_datetime(df['Joined Bank'], format='%d-%m-%Y')
print(df['Joined Bank'].dtype)
# Out:
# datetime64[ns]

# %% [markdown]
# ## Univariate analysis and visualization

# %%
sns.set_style("whitegrid")   # clean background
plt.figure(figsize=(15, 10))

colors = sns.color_palette("viridis", len(numerical_cols))  # nice color palette

for i, col in enumerate(numerical_cols):
    plt.subplot(4, 3, i + 1)
    sns.histplot(df[col], kde=True, color=colors[i], bins=30)
    plt.title(col, fontsize=12, fontweight="bold")
    plt.xlabel(col, fontsize=10)
    plt.ylabel("Count")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Select numerical columns for correlation analysis

# %%
numerical_cols = ['Age', 'Estimated Income', 'Superannuation Savings', 'Credit Card Balance',
                  'Bank Loans', 'Bank Deposits', 'Checking Accounts', 'Saving Accounts',
                  'Foreign Currency Account', 'Business Lending', 'Properties Owned']

# Calculate the correlation matrix
correlation_matrix = df[numerical_cols].corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='YlGnBu', fmt=".2f")
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %% [markdown]
# ## Bivariate Analysis: Regression Plots of Selected Feature Pairs

# %%
pairs_to_plot = [
    ('Bank Deposits', 'Saving Accounts'),
    ('Checking Accounts', 'Saving Accounts'),
    ('Checking Accounts', 'Foreign Currency Account'),
    ('Age', 'Superannuation Savings'),
    ('Estimated Income', 'Checking Accounts'),
    ('Bank Loans', 'Credit Card Balance'),
    ('Business Lending', 'Bank Loans'),
]


for x_col, y_col in pairs_to_plot:
    plt.figure(figsize=(8, 6))
    sns.regplot(
        data=df,
        x=x_col,
        y=y_col,
        scatter_kws={'alpha': 0.4},     # semi-transparent points
        line_kws={'color': 'red'}       # best-fit line color
    )
    plt.title(f'Relationship between {x_col} and {y_col}', fontsize=14)
    plt.xlabel(x_col, fontsize=12)
    plt.ylabel(y_col, fontsize=12)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Insights:

# %% [markdown]
# 1. **Deposits and Savings Behavior**
#    The strong correlation between *Bank Deposits* and *Saving Accounts* indicates overlapping financial behavior: customers who frequently deposit funds are also more likely to maintain or grow their savings balances. This suggests these features may capture similar aspects of liquidity preference.
#
# 2. **Income, Age, and Wealth Accumulation**
#    Moderate correlations of *Age* and *Estimated Income* with *Superannuation*, *Savings*, and *Checking Accounts* reflect a financial lifecycle pattern. Older and higher-income individuals typically accumulate greater savings and retirement funds, but may also hold higher credit card balances and loans.
#
# 3. **Low Correlation with Property Ownership**
#    The weak relationship between *Properties Owned* and other banking variables implies that property acquisition depends on external factors (e.g., real estate markets, inheritance, location) rather than core banking activity.
#
# 4. **Business vs. Personal Banking**
#    *Business Lending* shows moderate correlation with *Bank Loans*, suggesting some overlap between personal and business borrowing. However, its low correlation with deposits and property-related metrics indicates it largely serves a distinct customer segment with separate financial behaviors.
